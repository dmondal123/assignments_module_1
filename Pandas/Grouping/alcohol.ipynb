# %% [markdown]
# Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import the dataset from this address.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %% [markdown]
# Assign it to a variable called drinks.

# %%
drinks = pd.read_csv(url, sep = ',')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# Which continent drinks more beer on average?

# %%
drinks.groupby('continent').beer_servings.mean().head(1)
# Out:
# continent
# AF    61.471698
# Name: beer_servings, dtype: float64

# %% [markdown]
# For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby('continent')[['beer_servings', 'wine_servings','total_litres_of_pure_alcohol']].mean()
# Out:
#            beer_servings  wine_servings  total_litres_of_pure_alcohol
# continent
# AF             61.471698      16.264151                      3.007547
# AS             37.045455       9.068182                      2.170455
# EU            193.777778     142.222222                      8.617778
# OC             89.687500      35.625000                      3.381250
# SA            175.083333      62.416667                      6.308333

# %% [markdown]
# Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent')[['beer_servings', 'wine_servings','total_litres_of_pure_alcohol']].median()
# Out:
#            beer_servings  wine_servings  total_litres_of_pure_alcohol
# continent
# AF                  32.0            2.0                          2.30
# AS                  17.5            1.0                          1.20
# EU                 219.0          128.0                         10.00
# OC                  52.5            8.5                          1.75
# SA                 162.5           12.0                          6.85

# %% [markdown]
# Print the mean, min and max values for spirit consumption.

# %%
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302
